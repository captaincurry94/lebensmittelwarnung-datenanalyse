# %%
import requests
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import the csv containing the scraped data

# %%
data = pd.read_csv('lebensmittelwarnungen.csv')

# %% [markdown]
# ## Analyze the data

# %% [markdown]
# ### Most common warning reasons
# Lets analyse the reasons for which products are being called back.

# %%
data.head()
# Out:
#       warningtype        date  \
# 0    Lebensmittel  13.04.2022
# 1    Lebensmittel  12.04.2022
# 2    Lebensmittel  08.04.2022
# 3    Lebensmittel  07.04.2022
# 4    Lebensmittel  06.04.2022
#
#                                             producer  \
# 0                         Firma Fromagerie Jacquin
# 1      Jentschura International GmbH   Otto-Hahn-...
# 2      Ferrero Deutschland GmbH Hainer Weg 120 60...
# 3      Ferrero Deutschland GmbH\r Hainer Weg 120\...
# 4      Ferrero Deutschland GmbH\r Hainer Weg 120\...
#
#                                              product  \
# 0                                    Selles sur Cher
# 1  WurzelKraftPflanzliches Feingranulat zum Verze...
# 2  Erneute Ausweitung des Rückrufes von diversen ...
# 3  Erneute Ausweitung des Rückrufes von diversen ...
# 4  Ausweitung des Rückrufes von diversen Schokola...
#
#                                               reason  \
# 0  Verdacht auf Kontamination mit unerwünschten B...
# 1                           Nachweis von Salmonellen
# 2  Die genannten Produkte stehen in einem mutmaßl...
# 3  Die genannten Produkte stehen in einem möglich...
# 4  Die genannten Produkte stehen in einem möglich...
#
#                                                state  \
# 0       Bayern, Berlin, Nordrhein-Westfalen, Sachsen
# 1  Baden-Württemberg, Bayern, Berlin, Hessen, Nie...
# 2  Baden-Württemberg, Bayern, Berlin, Brandenburg...
# 3  Baden-Württemberg, Bayern, Berlin, Brandenburg...
# 4  Baden-Württemberg, Bayern, Berlin, Brandenburg...
#
#                           source  \
# 0                            NaN
# 1  Jentschura International GmbH
# 2       Ferrero Deutschland GmbH
# 3       Ferrero Deutschland GmbH
# 4       Ferrero Deutschland GmbH
#
#                                            thumbnail  \
# 0  https://www.lebensmittelwarnung.de/bvl-lmw-de/...
# 1  https://www.lebensmittelwarnung.de/bvl-lmw-de/...
# 2  https://www.lebensmittelwarnung.de/bvl-lmw-de/...
# 3  https://www.lebensmittelwarnung.de/bvl-lmw-de/...
# 4  https://www.lebensmittelwarnung.de/bvl-lmw-de/...
#
#                                          detail_link
# 0  https://www.lebensmittelwarnung.de/bvl-lmw-de/...
# 1  https://www.lebensmittelwarnung.de/bvl-lmw-de/...
# 2  https://www.lebensmittelwarnung.de/bvl-lmw-de/...
# 3  https://www.lebensmittelwarnung.de/bvl-lmw-de/...
# 4  https://www.lebensmittelwarnung.de/bvl-lmw-de/...

# %%
data.reason.value_counts()
# Out:
# Salmonellen                                                                                                                                                11
# Ethylenoxid                                                                                                                                                 8
# Grenzüberschreitung bzgl. Ethylenoxid                                                                                                                       5
# Ethylenoxid oberhalb der zulässigen Höchstmengen nachgewiesen                                                                                               4
# Der festgestellte Ethylenoxid-Gehalt liegt über dem zugelassenen Grenzwert.                                                                                 4
#                                                                                                                                                            ..
# Bei dem Produkt kann nicht ausgeschlossen werden, dass vereinzelt Glassplitter enthalten sein könnten.                                                      1
# Es besteht der Verdacht, dass möglicherweise das Allergen Sellerie enthalten ist, jedoch nicht im deutschsprachigen Zutatenverzeichnis aufgeführt wird.     1
# Verdacht von Glassplittern im Produkt                                                                                                                       1
# Erhöhter Glutengehalt in als "glutenfrei" bezeichnetem Produkt.                                                                                             1
# Erhöhter Gehalt an Ethylenoxid (2-Chlorethanol)                                                                                                             1
# Name: reason, Length: 203, dtype: int64

# %% [markdown]
# At first glance, salmonella seem to be the most common reason but Ethylenoxid is in second place and with a differing title also in third place. We will thus have to identify if there are any reasons that occur with multiple different spellings. Create a list of common categories to categorize each entry.

# %%
data.reason.unique()
# Out:
# array(['Verdacht auf Kontamination mit unerwünschten Bakterien Listeria Monocytogenes.',
#        'Nachweis von Salmonellen',
#        'Die genannten Produkte stehen in einem mutmaßlichen Zusammenhang mit einem Salmonellen-Ausbruchsgeschehen',
#        'Die genannten Produkte stehen in einem möglichen Zusammenhang mit einem Salmonellen-Ausbruchsgeschehen.',
#        'nicht deklariertes Milcheiweiß',
#        'Eigenuntersuchungen haben gezeigt, dass das Produkt Salmonellen aufweisen kann',
#        'nicht deklariertes Allergen Sulfit',
#        'Fehlende Kennzeichnung des allergenen Zusatzstoffes Schwefeldioxid',
#        'Belastung mit Ethylenoxid',
#        'Aufgrund eines Etikettierungsfehlers auf dem Becher-Boden und auf der Becher-Seite kann bei einzelnen Produkten mit der Deckel-Etikettierung Garnelensalat mit Cocktail-Creme (125 g) der Marke NADLER die Ausweisung der Allergene Garnelen, Sahne und Natriummetabisulfit und die Spurenhinweise für Fisch, Soja, Sellerie, Sesam und Gluten fehlen.',
#        'Nachweis von Photoinitiatoren',
#        'Im Anreichungsverfahren in 25 g der Probe wurden Salmonellen nachgewiesen.',
#        'Es wurden in einer Probe Salmonellen nachgewiesen.',
#        'Mögliche Kontamination mit Salmonella Newport und Cronobacter sakazakii',
#        'Erhöhte Grenzwerte des Schimmelpilzgiftes Ochratoxin A',
#        'Ethylenoxid', 'mögliche Gefahr durch Glasscherben',
#        'Es kann nicht ausgeschlossen werden, dass in einzelnen Packungen eine Vermischung mit Nougateiern stattgefundenhat und somit die Allergenkennzeichnung nicht korrekt ist.',
#        'Es kann nicht ausgeschlossen werden, dass sich in den Packungen der genannten Charge Fremdkörper aus Hartplastik befinden.',
#        'Mögliche Verschluckungs-/Gesundheitsgefahr',
#        'Nachweis des Allergens Soja bei 3 Chargen',
#        'Aktualisierung der Veröffentlichung vom 11.03.2022, Charge E206824 / MHD 31.10.2023:es sind die weiteren Chargen E213278 / MHD 31.01.2024 und E217689 / MHD 31.07.2024 betroffen.Es kann nicht ausgeschlossen werden, dass ein höher Anteil Erdnuss enthalten ist, als durch die Spurenkennzeichnung abgedeckt. Dies kann eine Gesundheitsgefahr für ErdnussallergikerInnen darstellen.',
#        'Erhöhter Gehalt an Ethylenoxid (2-Chlorethanol)',
#        'Aufgrund einer möglichen Nachgärung kann sich in den Flaschen Überdruck aufbauen, der unter Umständen zum Bersten der Flaschen führen kann.',
#        'Der festgestellte Ethylenoxid-Gehalt liegt über dem zugelassenen Grenzwert.',
#        'hohe Werte an Delta-9-Tetrahydrocannabinol (Delta-9-THC)',
#        'Erhöhte Gehalte an Aflatoxinen',
#        'Es kann nicht ausgeschlossen werden, dass ein höher Anteil Erdnuss enthalten ist, als durch die Spurenkennzeichnung abgedeckt. Dies kann eine Gesundheitsgefahr für ErdnussallergikerInnen darstellen.',
#        'Aus Gründen des vorbeugenden Verbraucherschutzes ruft die Prinsen B.V. die betroffene Ware zurück. Es kann nicht ausgeschlossen werden, dass in einzelnen Protein Bars des betreffenden MHD Glasstücke enthalten sein können.',
#        'In dem Produkt wurde ein verbotener Farbstoff nachgewiesen.',
#        'Fehlerhafte Allergendeklaration (Sellerie)',
#        'In der Ware wurde 2-Chlorethanol nachgewiesen, daher wird vom Verzehr des obengenannten Produktes aus der angegebenen Produktcharge dringend abgeraten.',
#        'Das Produkt hat einen zu hohen Gehalt an Chlorat.',
#        'Erhöhte PAK-Gehalte. Einige Vertreter der PAK (polyaromatische Kohlenwasserstoffe) wirken mit großer Wahrscheinlichkeit erbgutverändernd und krebserregend.',
#        'Es besteht die Gefahr, dass Kunststoffteile in das Produkt gelangt sind.',
#        'Es kann nicht ausgeschlossen werden, dass das Produkt eine erhöhte Rückstandmenge an Nikotin enthält.',
#        'MDMA (auch bekannt als Ecstasy)\r\rLassen Sie die Flasche unberührt, wenn der Inhalt von dem abweicht, was für Champagner üblich ist. Mit MDMA gefüllte Flaschen sind außen nicht von mit Champagner gefüllten Flaschen zu unterscheiden. Beim Gießen gibt es jedoch einen deutlichen Unterschied. Das flüssige MDMA:\r\rSprudelt NICHT\rHat eine rötlich-braune Farbe, die sich mit der Zeit verdunkelt\rHat einen anderen Anisgeruch.',
#        'fehlende Allergenkennzeichnung von Schwefeldioxid',
#        'In der Ware wurde 2-Chlorethanol nachgewiesen.',
#        'In der Zutat Zimt/Lebkuchengewürz, die in den betroffenen Produkten verwendet wurde, sind geringe Rückstände von 2-Chlorethanol, einem Reaktionsprodukt des Pflanzenschutzmittels Ethylenoxid, nachgewiesen worden',
#        'In den oben genannten Produkten sind Rückstände von 2-Chlorethanol, einem Abbauprodukt von Ethylenoxid,  nachgewiesen worden.',
#        'Ein Bersten einzelner Flaschen kann nicht ausgeschlossen werden.',
#        'Es kann nicht ausgeschlossen werden, dass in einzelnen Haferriegeln Salmonellen enthalten sind.',
#        'Nachweis von Salmonella spp.',
#        'In dem oben genannten Produkt sind geringe Rückstände von 2-Chlorethanol, einem Reaktionsprodukt des Pflanzenschutzmittels Ethylenoxid, nachgewiesen worden.',
#        '2-Chlorenthanol in vegetarischen Instant Reisnudeln',
#        'In dem betroffenen Produkt ist die Zutat Vollmilchpulver enthalten, welche jedoch nicht auf der Verpackung deklariert ist.',
#        'In der Zutat „Zimt gemahlen“, die in den betroffenen Produkten verwendet wurde, sind geringe Rückstände von 2-Chlorethanol, einem Reaktionsprodukt des Pflanzenschutzmittels Ethylenoxid, nachgewiesen worden.',
#        'In der Zutat „Zimt gemahlen“, die in den betroffenen Produkten verwendet wurde, sind geringe Rückstände von 2-Chlorethanol, einem Reaktionsprodukt des Pflanzenschutzmittels Ethylenoxid, nachgewiesen worden',
#        'In der Zutat „Zimt gemahlen“, die in den oben genannten Produkt verwendet wurde, sind geringe Rückstände von 2-Chlorethanol, einem Reaktionsprodukt des Pflanzenschutzmittels Ethylenoxid, nachgewiesen worden.',
#        'Erhöhter Curcumin- und Piperingehalt. Bei empfindlichen Personen kann eine Einnahme zu negativen gesundheitlichen Wirkungen führen. Schwangere sollten auf die Einnahme gänzlich verzichten.Das Produkt wurde online gehandelt.',
#        'erhöhter Anteil an Bittermandeln in einzelnen Packungen',
#        'Grund: erhöhter Blausäuregehalt', 'erhöhter Blausäuregehalt',
#        'Bisphenol A und CDB in Kokosnusscreme',
#        'Es kann nicht ausgeschlossen werden, dass einzelne Packungen einen erhöhten Anteil an Bittermandeln enthalten.',
#        'Zu hoher Gehalt an Blausäure',
#        'In einzelnen Fällen ist nicht auszuschließen, dass Fremdkörper aus Glas in das Produkt gelangt sein können.',
#        'Grund für den Rückruf ist der erhöhte Anteil an Bittermandeln, weswegen in dem Produkt Blausäure enthalten ist',
#        'Rückstände von 2-Chlorethanol in einer Zutat des Produktes',
#        'Es besteht der Verdacht, dass möglicherweise das Allergen Sellerie enthalten ist, jedoch nicht im deutschsprachigen Zutatenverzeichnis aufgeführt wird.',
#        'In der Zutat „Zimt gemahlen“, die in den oben genannten Produkten verwendet wurde, sind geringe Rückstände von 2-Chlorethanol, einem Abbauprodukt des Pflanzenschutzmittels Ethylenoxid, nachgewiesen worden.',
#        'Salmonellen',
#        'Es wurde festgestellt, dass die in dieser Charge verarbeiteten Dillspitzen Mehltau aufweisen.',
#        'überhöhte Gehalte an Prochloraz und Pyridaben',
#        'Möglicher Schimmelbefall',
#        'Im Rahmen einer Routinekontrolle wurden in einer Einzelprobe Salmonellen festgestellt.',
#        'Das Produkt enthält das Allergen Sulfit, welches nicht in der Zutatenliste aufgeführt ist.',
#        'Eine Salmonellenbelastung kann nicht ausgeschlossen werden.',
#        'Fund von Glassplittern einer einzelner Verbraucherin. Daher erfolgt ein Rückruf aufgrund des Vorsorgeprinzips.',
#        'Es kann nicht ausgeschlossen werden, dass sich in dem Produkt 2-Chlorethanol befindet.',
#        'Sensorische Veränderungen aufgrund von Spuren eines für die Lebensmittelproduktion vorgesehenen, essigbasierten Reinigungsmittels.',
#        'Nicht im Zutatenverzeichnis gekennzeichneter Weizen. Es besteht eine mögliche Gesundheitsgefahr aufgrund allergischer Reaktionen.',
#        'Nachweis von 2-Chlorethanol in der Zutat Curryblattextrakt',
#        'Im Rahmen einer Untersuchung wurden geringe Rückstände von 2-Chlorethanol in der Zutat Zimt nachgewiesen.',
#        'Nachweis von 2-Chlorethanol',
#        'Es kann nicht ausgeschlossen werden, dass das genannte Produkt Erdnüsse enthält.',
#        'Es kann nicht ausgeschlossen werden, dass es in Einzelfällen durch Verunreinigungen durch Hefen zu einem Gärprozess kommt, welcher zu einem Bersten der Flaschen führen kann.',
#        'Nicht gekennzeichnetes Allergen Sesam',
#        'Nachweis von Ethylenoxid',
#        'Überschreitung Rückstandshöchstgehalt Pflanzenschutzmittel Anthrachinon',
#        'Rückstände von Ethylenoxid', 'Nicht deklariertes Allergen Sulfit',
#        'Nicht deklariertes Allergen (Haselnuss)',
#        'Bei einer Stichprobe im Rahmen einer Eigenkontrolle wurde ein erhöhter Gehalt an Mykotoxinen (Ochratoxin-A) gefunden.',
#        'Fremdkörper (Metalldraht)',
#        'Grund für den Rückruf sind Fremdkörper (rote Plastikteile) in der betroffenen Charge.',
#        'nicht deklariertes Allergen (Erdnuss)',
#        'Pflanzenschutzmittelrückstand',
#        'Es kann nicht ausgeschlossen werden, dass sich in einzelnen Standbeuteln mit dem Mindesthaltbarkeitsdatum 07.05.2023 dunkle Fremdkörper befinden.',
#        'Nicht deklarierte Allergene Mandel und Pistazie',
#        'Es wurde in einer Probe Listeria monocytogenes nachgewiesen.',
#        'Es wurden in einer Probe der MHD 07/2022 Salmonellen nachgewiesen.',
#        'Wie das Unternehmen mitteilt, wurden in einer Probe\rSalmonellen nachgewiesen.',
#        'Glassplitter im Produkt',
#        'Es kann nicht ausgeschlossen werden, dass Gluten in dem Produkt enthalten ist',
#        'Feststellung von Salmonellen',
#        'Im Produkt befinden sich Rückstände des Allergens Erdnuss',
#        'Es wurden in einer Probe der Charge 07/2022 Salmonellen nachgewiesen.',
#        'Nachweis Salmonellen',
#        'Es kann nicht ausgeschlossen werden, dass in einzelnen Gläsern größere Glasscherben enthalten sind.',
#        'Im Rahmen der Qualitätssicherung wurde festgestellt, dass einzelne Flaschen eine Gärung durchlaufen, was zu einer Alkoholbildung und zum Bersten der Flaschen führen kann.',
#        'Rückstandshöchstgehaltsüberschreitung mit dem Pflanzenschutzmittel Chlorpyrifos',
#        'Glasfragmente',
#        'Nachweis von Vero-/Shigatoxin-bildenden Escherichia coli (VTEC/STEC)',
#        'Es fehlt der Allergikerhinweis "Enthält Sulfite" auf folgenden LOTs: - L6495- L6825.Die betroffene Ware kann an den ersten vier Ziffern der Losnummern  L6495 und L6825 auf der Verpackungsoberseite neben dem Verschluss erkannt werden.',
#        'Es kann nicht ausgeschlossen werden, dass sich in vereinzelten Gläsern kleine transparente Glassplitter befinden können.',
#        'Es kann nicht ausgeschlossen werden, dass sich an der Oberfläche Schimmelspurengebildet haben, die sich in Form weiß/bräunlicher Punkte äußern.',
#        'Grund des Rückrufes: Es kann nicht ausgeschlossen werden, dass sich in den Produkten Rückstände von Ethylenoxid befinden.',
#        'In einer Packung des Artikels wurde ein Fremdkörper gefunden. Es kann nicht ausgeschlossen werden, dass weitere kleine Fremdkörperstücke in einzelnen Packungen enthalten sein können.',
#        'Im Anreichungsverfahren in 25 g der Probe wurden Salmonellen des Serotyps Salmonella Amsterdam nachgewiesen.',
#        'Bei dem genannten Produkt kann nicht ausgeschlossen werden, dass sich an der oberen Innenseite des Glases Risse bilden und es zu Glasbruch/Absplitterungen kommt, welche in das Produkt gelangen können.',
#        'Bei den betroffenen Produkten wurde ein erhöhter Gehalt an Ergotalkaloiden festgestellt.',
#        'Nachweis von Ergotalkaloiden (Stoffwechselprodukte sogenannter Mutterkornpilze).',
#        'Erstickungsgefahr aufgrund der Inhaltszusatzstoffe Carageen (E407) und Johannisbrotkernmehl (E410) in Gelee-Süßware.',
#        'Möglicher Verderb des Produktes durch Schimmel oder Hefebildung (Vergärung) vor Ablauf des angegebenen Mindesthaltbarkeitsdatums.',
#        'Aflatoxine in Mandeln aus Spanien',
#        'Es kann nicht ausgeschlossen werden, dass in den betroffenen Lebensmitteln Rückstände des in der EU nicht zugelassenen Pflanzenschutzmittels Ethylenoxid enthalten sind.',
#        'Überschreitung des Rückstandshöchstgehalts des Pflanzenschutzmittels Chlorpyrifos',
#        'Überschreitung des Rückstandshöchstgehalts von Ethylenoxid',
#        'Beim vorliegenden Produkt wurde ein erhöhter Gehalt an Aflatoxine (B1, B2, G1 und G2) festgestellt.',
#        'Ethylenoxid-Grenzwertüberschreitung in Rohstoff Moringablattpulver',
#        'Die betroffene Ware wird aufgrund von fehlender Kennzeichnung des Allergens Sulfit zurückgerufen.',
#        'In den genannten hanfhaltigen Lebensmitteln wurde ein erhöhter Gehalt an Tetrahydrocannabinol (THC) festgestellt.',
#        'Es wurde ein erhöhter Gehalt an Tetrahydrocannabinol (THC) festgestellt.',
#        'Eine minimale Belastung mit dem Biozid Ethylenoxid kann nicht ausgeschlossen werden.',
#        'Mögliche falsche Auslobung als Cashewmus. In den Gläsern der genannten Charge kann sich fälschlicherweise Erdnussmus befinden, das sich in Optik und Geruch deutlich von Cashewmus unterscheidet. Menschen, die allergisch auf Erdnuss reagieren, können von diesem Produkt gesundheitlich beeinträchtigt werden.',
#        'Erhöhte Gehalte von Ethylenoxid', 'Glasscherben',
#        'Ethylenoxid-Feststellung (Summenparameter aus Ethylenoxid und 2-Chlorethanol) im Produkt;',
#        'Zu hohe Menge von Alpha-Liponsäure', 'Aflatoxine',
#        'Es kann nicht ausgeschlossen werden, dass sich Glas in dem Lebensmittel befindet.',
#        'erhöhter Gehalt an Ethylenoxid',
#        'Es kann nicht ausgeschlossen werden, dass die genannten Produkte eine geringe Menge an GVO im Reis-Mehl enthalten.',
#        'fehlende Allergenkennzeichnung der Allergene Milch und Soja',
#        'Höchstgehaltsüberschreitung von Benz(a)pyren und "Summe PAK4"',
#        'Überhöhter Wert an Ethylenoxid',
#        'Grenzüberschreitung bzgl. Ethylenoxid',
#        'Es kann nicht ausgeschlossen werden, dass sich in einzelnen Verpackungen dünne Metallspäne befinden.',
#        'Bei Verzehr des Produktes kann es zu Verletzungen durch Kunststoffsplitter kommen.',
#        'Salmonellen in in Halva aus Sonnenblumenkernen',
#        'Die aus den Verzehrempfehlungen des Artikels resultierende Tagesdosis überschreitet die sichere tägliche Aufnahmemenge',
#        'Im Rahmen von einer Eigenuntersuchung wurden Salmonellen festgestellt.',
#        'Aus Gründen des vorbeugenden Verbraucherschutzes- Befund von Salmonellen -  ruft die Herstellerfirma das Produkt der Marke Abido  (50 g) zurück.',
#        'Es kann nicht ausgeschlossen werden, dass sich in einzelnen Verpackungen metallische Fremdkörper befinden.',
#        'Es kann nicht ausgeschlossen werden, dass die oben genannten Produkte mikrobielle und substantielle Abweichungen aufweisen. Es wurden Schimmelpilze festgestellt, d.h. die betroffenen Lebensmittel sind nicht mehr für den Verzehr geeignet.',
#        'Verdacht von Glassplittern im Produkt', 'Glassplitter',
#        'In Eigenanalysen wurde festgestellt, dass die in den betroffenen Produkten enthaltenen Zwiebeln mit Blei belastet sind.',
#        'Mögliche Lackablösungen im Inneren der Konservendosen',
#        'Die benannten Eat Reals Puffs Produkte mit den Barcodenummern: 50264894898725026489489841alle Haltbarkeiten bis einschließlich Mai 2022 werden zurückgerufen, da das Produkt möglicherweise Milch enthält, die nicht auf dem Etikett aufgeführt ist und daher ein Risiko für Menschen mit einer Milchallergie darstellt.',
#        'mikrobielle und substantielle Abweichungen',
#        'erhöhter Delta-9-Tetrahydrocannabinol-Gehalt',
#        'Es kann nicht ausgeschlossen werden, dass das Produkt Erdnüsse und Haselnüsse enthält, die eine Gesundheitsgefahr für Allergiker darstellen kann.',
#        'In den genannten Gläsern kann sich anstatt des auf dem Etikett deklarierten Menüs "Spinat-Käse-Risotto" das Menü "Gemüse mit Spaghetti und Pute" befinden.',
#        'Mögliche Belastung mit Salmonellen',
#        'Mögliche Verunreinigung mit Sellerie',
#        'Mögliche falsche Auslobung mit Tomate und Basilikum. In den betroffenen Gläsern kann sich fälschlicherweise enerBiO Streich-creme mit Paprika und Cashewnüssen befinden. Cashewnüsse können allergische Reaktionen hervorrufen.',
#        'Nachweis von Salmonellen in einer Zutat',
#        'Es ist nicht auszuschließen, dass Flaschen vereinzelt mit Rückständen von Lösemitteln verunreinigt sind, die sich in Geruchs- und Geschmacksabweichungen äußern können.',
#        'In vereinzelten Flaschen können sich Glasfragmente/Glasgries befinden',
#        'Es ist nicht auszuschließen, dass sich spitze metallische Fremdkörper im Produkt befinden',
#        'Das Produkt enthält den verschreibungspflichtigen Wirkstoff „Sildenafil“ in pharmakologisch wirksamer Menge sowie die für Lebensmittel nicht zugelassene Zutat „Epimedium“.',
#        'Das Getränk schäumt beim Öffnen stark über, da es gärt.Durch die Gärung kann die Flasche zerbrechen.Das Getränk ist nicht mehr alkoholfrei.',
#        'Es kann nicht ausgeschlossen werden, dass sich einzelne Glasstücke in den Sushi-Reis Packungen befinden.',
#        'Erhöhter Schwefeldioxidgehalt, fehlende Kennzeichnung des Allergens Schwefeldioxid',
#        'Fremdkörper (transparente Hartplastikteile)',
#        'Erhöhter Gehalt an Chlorpyrifos',
#        'In den betroffenen Produkten der Marke SULTAN wurden Sesamsamen mit erhöhtem Gehalt an Ethylenoxid verarbeitet.',
#        'Aus Gründen des vorbeugenden Verbraucherschutzes wird der Artikel "Edeka Bio Heidelbeere in Birne nach dem 4. Monat" im 190-Gramm-Glas aufgrund eines Fremdkörper (Glasstücke) zurück gerufen.',
#        'Bei einem Stück aus dem Lot wurden Enterohämorrhagische Escherichia coli Erreger (EHEC) festgestellt.',
#        'Ethylenoxid oberhalb der zulässigen Höchstmengen nachgewiesen',
#        'gesundheitliche Gefährdung für Allergiker von Mandeln durch Falschetikettierung',
#        'Überschreitung der zulässigen Höchstmenge von Rückständen eines Antibiotikums',
#        'Das Produkt enthält möglicherweise Glasstücke.',
#        'Grund hierfür ist, dass im Rahmen einer internen Untersuchung Rückstände des Pflanzenschutzmittels Ethylenoxid in der enthaltenen Sesamsaat festgestellt wurden.',
#        'Grund für den vorsorglichen Rückruf des betroffenen Artikels ist der fehlende Allergenhinweis auf Soja.',
#        'Erhöhter Glutengehalt in als "glutenfrei" bezeichnetem Produkt.',
#        'Glaspartikel', 'Bei dem Artikel wurden Salmonellen festgestellt.',
#        'Erhöhte Werte an Pyrrolizidinalkaloiden (PA) und Tropanalkaloiden (TA)',
#        'Es kann nicht ausgeschlossen werden, dass in dem betroffenen Produkt Noroviren enthalten sind.',
#        'Es kann nicht ausgeschlossen werden, dass in einigen Gläsern Glasscherben enthalten sind.',
#        'mögliche Gefahr durch Bombage',
#        'Es ist nicht mit absoluter Sicherheit auszuschließen, dass im oben genannten Artikel vereinzelt Glasbruchstücke enthalten sind.',
#        'Es kann nicht ausgeschlossen werden, dass in dem betroffenen Produkt erhöhte Werte an Pyrrolizidinalkaloiden enthalten sind.',
#        'Hoher Jodgehalt',
#        'Es könnte sein, dass sich in einigen wenigen Packungen des Produktes kleine Metallsplitter befinden.',
#        'Bei dem aufgeführten Artikel wurden Salmonellen festgestellt.',
#        'Nicht gekennzeichnetes Allergen (Milch)',
#        'Bei den Produkten kann nicht ausgeschlossen werden, dass vereinzelt Glassplitter enthalten sein könnten.',
#        'Bei dem Produkt kann nicht ausgeschlossen werden, dass vereinzelt Glassplitter enthalten sein könnten.',
#        'Befund von Pyrrolizidinalkaloiden',
#        'Grund für den Rückruf ist ein erhöhter THC-Gehalt.',
#        'Falschetikettierung',
#        'fehlerhafte Allergenkennzeichnung in Bezug auf Senf, Sesam und Sellerie',
#        'Das Nahrungsergänzungsmittel enthält den Arzneimittel-Wirkstoff Sildenafil',
#        'Verdacht auf Glasfremdkörper',
#        'Es kann nicht ausgeschlossen werden, dass sich im Einzelfall Glassplitter im betroffenen Produkt befinden.',
#        'erhöhter THC-Gehalt',
#        'Es besteht die Möglichkeit, dass vereinzelt Glassplitter aus dem Mahlwerk der fehlerhaften Glas-Keramikmühlen herausfallen können.',
#        'Chloratgehalt'], dtype=object)

# %% [markdown]
# #### Creating a Wordcloud
# Plotting a simple wordcloud can give us a feeling for the content that we can expect in the description fields. We filter out common stop words as well as words that occur often in the descriptions but that are not related to the reason for which a product is taken off the market.

# %%
#get list of German stopwords like "and" "or" and others
stopwords = requests.get('https://raw.githubusercontent.com/stopwords-iso/stopwords-de/master/stopwords-de.txt').text.split('\n')

# %%
stopwords_addition = ['am', 'an', 'artikel', 'aufgrund', 'ausgeschlossen', 'befinden', 'betroffenen', 'charge', 'das', 'der', 'die', 'durch', 'einzelnen', 'enthalten', 'enthält', 'erhöhte', 'erhöhter', 'erhöhter', 'festgestellt', 'flaschen', 'führen', 'gefunden', 'gehalt', 'genannten', 'gering', 'geringe', 'grund', 'im', 'kann', 'mit', 'mögliche', 'nachgewiesen', 'nachweis', 'nicht', 'probe', 'produkt', 'produkte', 'produkten', 'produktes', 'rahmen', 'verwendet', 'werden', 'zutat']

# %%
#generate the wordcloud
wordcloud = WordCloud(max_font_size=20, max_words=40, width=400, height=300, background_color="white", stopwords=stopwords + stopwords_addition).generate(' '.join(data.reason.unique()).lower())
plt.figure(figsize=(8, 6), dpi=100)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Data Cleaning and Encoding
# First, let's remove an outlier in the state column. There is one row that in its list of applicable states also contains "Deutschland" which is not a state in Germany but the whole country itself. Thus, we will remove this row.

# %%
data.drop(data[data["state"].str.contains("Deutschland")].index, inplace=True)

# %%
#create list with common reasons
common_reasons = [
    "Salmonellen",
    "Chlorpyrifos",
    "Glas",
    "Ethylenoxid",
    "Allergen",
    "Allergiker",
    "Fremdkörper",
    "Schimmel",
    "Johannisbrotkernmehl",
    "Schimmel",
    "Plastik",
    "Aflatoxin",
    "Metall",
    "Jod",
    "Blei",
    "Nüsse",
    "Sellerie",
    "Pyrrolizidinalkaloid",
    "THC",
    "Allergen",
    "Plastik",
    "Erdnuss",
    "Chlorethanol",
    "falsche Auslobung"
]

# %% [markdown]
# Let's append the reason categories and the countries as individual one-hot encoded features to our dataset

# %%
#create a new column for each major reason and one-hot encode if it is part of the description
for reason in common_reasons:
    data['reason_' +  reason] = data["reason"].apply(lambda x: 1 if reason.lower() in str(x).lower() else 0)

# %%
#create a list with all possible states (Bundesländer)
statelist = []
for states in data.state:
    for state in states.split(','):
        statelist.append(state.strip()) 
statelist = set(statelist)

# %%
#one-hot encode the possible states and append a column with each state to the dataframe
for state in statelist:
    data['state_' + state] = data["state"].apply(lambda x: 1 if state in [word.strip() for word in x.split(',')] else 0)

# %% [markdown]
# Now, the dataframe contains a one-hot encoded column for each major reason category and for each state. This will make plotting and analysis much easier than having this data nested in lists within columns.

# %%
#look at exemplary one-hot encoded data for state=Berlin and reason=Salmonellen
data[["state","state_Berlin","reason_Salmonellen"]]
# Out:
#                                                  state  state_Berlin  \
# 0         Bayern, Berlin, Nordrhein-Westfalen, Sachsen             1
# 1    Baden-Württemberg, Bayern, Berlin, Hessen, Nie...             1
# 2    Baden-Württemberg, Bayern, Berlin, Brandenburg...             1
# 3    Baden-Württemberg, Bayern, Berlin, Brandenburg...             1
# 4    Baden-Württemberg, Bayern, Berlin, Brandenburg...             1
# ..                                                 ...           ...
# 244  Baden-Württemberg, Bayern, Berlin, Brandenburg...             1
# 245  Baden-Württemberg, Bayern, Hessen, Niedersachs...             0
# 246  Baden-Württemberg, Bayern, Berlin, Brandenburg...             1
# 247  Bayern, Hamburg, Niedersachsen, Nordrhein-West...             0
# 248  Baden-Württemberg, Bayern, Berlin, Brandenburg...             1
#
#      reason_Salmonellen
# 0                     0
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ..                  ...
# 244                   0
# 245                   0
# 246                   0
# 247                   0
# 248                   0
#
# [248 rows x 3 columns]

# %% [markdown]
# ### Data Visualization
# Looking at the most mentioned reasons, we can see Ethylenoxid and Salmonella to be the most mentioned reasons. Ethylenoxid is a pesticide that is known to cause cancer and that is forbidden in the EU.

# %%
reason_count = data[["reason_" + col for col in common_reasons]].sum().sort_values()
reason_count.index = [idx.replace("reason_","") for idx in reason_count.index]
reason_count_pct = reason_count.apply(lambda x: x/len(data)*100)
reason_count_pct.plot(kind="barh", figsize=(12,8), fontsize=15)

# %% [markdown]
# The occurrence of glas seems to be comparatively low at first glance. But there are also the categories of Fremdkörper, Metall and Plastik. As those are all dangerous items that got mixed up in the food accidentally, it could make sense to group them together in an extra column to get a better understanding about how often parts of the production machinery falling into the food are reason for a callback.
#
# Now, the plot looks a little different as "Fremdkörper" are included almost as often as salmonella

# %%
#modify Fremdkörper column to subset all reasons containing mechanical parts being accidentally put into the food
data["reason_Fremdkörper"] = data["reason"].apply(lambda x: 1 if ("glas" in x.lower() or "fremdkörper" in x.lower() or "metall" in x.lower() or "plastik" in x.lower()) else 0)

#redefine and replot the count of reasons
reason_count = data[["reason_" + col for col in common_reasons]].sum().sort_values()
reason_count.index = [idx.replace("reason_","") for idx in reason_count.index]
reason_count_pct = reason_count.apply(lambda x: x/len(data)*100)
reason_count_pct.plot(kind="barh", figsize=(12,8), fontsize=15, title="Anteilige Nennungen von Gründen für Produktrückrufe in %")

# %% [markdown]
# Looking at the most mentioned producers, we can see that no producer is mentioned particularly often - most of them only once. I have recently heard about the supplement company "Bärbel Drexel" and the chocolate brand "Ferrero" that they had multiple consecutive product recalls which we can see in the data as well as both are among the top mentioned companies.

# %%
data.producer.value_counts()[:15].sort_values().plot(kind="barh")

# %% [markdown]
# Plotting how often a region is mentioned shows us that the state mentioned most often (NRW) is mentioned 30% more often than the least mentioned state (Mecklenburg-Vorpommern).

# %%
#create series with occurrence count for each region
state_count = data[['state_' + region for region in statelist]].sum().sort_values()
state_count.index = [idx.replace("state_","") for idx in state_count.index]
#create series with partial count for each region in % of total count
state_count_pct = state_count.apply(lambda x: round(x/len(data)*100,1))

# %%
fig, axes = plt.subplots(ncols=2)
axes[0].set_title(label="Absolute Occurrences")

axes[1].set_title(label="Relative Occurrences in %")

state_count.plot(kind='barh',figsize=(12,8), fontsize=12, ax=axes[0])
state_count_pct.plot(kind='barh', figsize=(12,8),ax=axes[1], xlim=(0,100))
axes[1].set_yticklabels([])
plt.show()
